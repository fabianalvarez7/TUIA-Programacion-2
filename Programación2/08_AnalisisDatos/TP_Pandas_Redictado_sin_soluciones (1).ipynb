# %% [markdown]
# # Trabajo Práctico Pandas 🐼
#
# ### Integrantes
# 🐼 1. _completar_ \\
# 🐼 2. _completar_ \\
# 🐼 3. _completar_ \\

# %% [markdown]
# ### Objetivos
#
# * 🐼 Realizar un analisis descriptivo/exploratorio de los resultados definitivos de las Elecciones Generales 2019 Provincia de Buenos Aires, desagregados por partido. Los mismos pueden encontrarse [aquí](https://catalogo.datos.gba.gob.ar/dataset/resultados-electorales/archivo/e3a19844-dc7d-4b8d-93e4-2d6f3131ca1d).
#
#   **Nota** Los datos corresponden a un caso de uso real, y como tal, **no son perfectos**. Prestar especial atención a la _limpieza_ del dataset.
#
# * 🐼 Se deberán tomar decisiones a lo largo del trabajo y **cada elección de diseño debe ser detallada explícitamente, y de ser posible, justificada**. Las elecciones que tome son libres y hay más de una solución.
#
# * 🐼 Deberá, además, analizar los _resultados_ obtenidos, redactando alguna conclusión al final del trabajo.
#
# ### Criterios de evaluación
#
# * 🐼 El uso de `pandas` para analizar todos sus datos es **obligatorio**. Aproveche las ventajas que ofrecen sus estructuras de datos para evitar todo lo posible los bloques de programación estructurada( `for`, `if`, etc.).
#
# * 🐼 La claridad del código será agradecida. Utilice nombres de variables significativos. Si los filtros se ponen largos pueden crearlos en líneas aparte. Considere utilizar funciones si ello facilita la lectura.
#
# ### Forma de entrega
#
# El trabajo se entregará en grupos de dos o tres integrantes.
# Se deberá entregar el Jupyter Notebook donde se realizó el análisis (uno por cada grupo).
# Estará disponible un buzón de entrega en el campus virtual de la materia hasta el viernes 07/07 a las 23hs.

# %% [markdown]
# ### Guía de análisis

# %% [markdown]
# 1. Leer el archivo. Visualizar algunos datos, explicar que significa cada columna.
# 2. Realizar un análisis de valores faltantes. Analizar que elegir como índice del dataframe.
# 3. Obtener estadísticas resumen de los datos presentados. De una breve interpretación de los mismos. ¿Observa una diferencia significativa entre el promedio y la media? ¿A qué cree que se debe?
# 4. ¿En que distrito se registró la mayor y menor cantidad de votos?. ¿A qué partido corresponde?
# 5. Verificar que la elección a intendente haya sido _justa_, es decir, que en cada partido, el intendente elegido sea del partido que obtuvo la mayor cantidad de votos.
# 6.  Los cuartiles  $𝑄1,𝑄2,𝑄3$  representan  25% ,  50% ,  75%  de los datos respectivamente, pueden obtenerlos usando describe. Para quitar valores "demasiado bizarros" de las observaciones, se utiliza el criterio de sacarlos si no están dentro del rango
#
#   $ [𝑄1−𝐼𝑄𝑅∗1.5, 𝑄3+𝐼𝑄𝑅∗1.5]
# $
#
#   donde  $𝐼𝑄𝑅=𝑄3−𝑄1$ es el "rango intercuartil" y representa la mitad de las observaciones del medio.
#   Hacer este procedimiento con los votos, y luego redondear todos los valores para que queden a múltiplos de  100.
#   Guardar el resultado de este procedimiento en un archivo `resultados_p6.csv`.
# 7. Realizar un grafico de torta con tres secciones que muestre cuantos votos obtuvieron 'FRENTE DE TODOS', 'JUNTOS POR EL CAMBIO' y el resto de los partidos.
# 8. Realizar un grafico que muestre cuantos votos obtuvieron todos los partidos que recibieron al menos diez mil votos. Elegir el tipo de gráfico que considere mejor.
# 9. Realizar un grafico de torta que muestre cuantos intendentes obtuvo cada partido.
# 10. Escriba una conclusión a modo de cierre del análisis presentado.

# %% [markdown]
# [Link secreto](https://en.wikipedia.org/wiki/Giant_panda) 🤫

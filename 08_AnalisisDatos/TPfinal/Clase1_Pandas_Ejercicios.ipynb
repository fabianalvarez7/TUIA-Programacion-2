# %% [markdown]
# ## Ejercicio 1 (15-20 mins):
#
# 1. Cargar el archivo `pokemon_data.txt` a un archivo. Deberán investigar el formato del archivo y buscar en las opciones de la función `read_csv` para poder cargarlo correctamente.
# 2. ¿Como se llaman las columnas de nuestro dataset? ¿Que tipo tiene cada una?
# 3. Elegir (y setear) un índice para el dataset.
# 4. Obtener el ataque promedio de un pokemon.
# 5. Obtener el ataque promedio de un pokemon de primera generacion.
# 6. Contar cuántos pokemones legendarios y no legendarios hay.
# 7. Investigar el método `.sort_values` utilizando la función `help` o la documentación de pandas. Utilizarlo para ordenar los pokemones por puntos de salud (HP) desde el mayor al menor.

# %%
import pandas as pd

# %% [markdown]
# Punto 1:

# %%
poke = pd.read_csv('pokemon_data.txt', delimiter = '\t')

# %% [markdown]
# Punto 2:

# %%
poke.head(0)
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
poke.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(poke['#'].head(0))
print(poke['Name'].head(0))
print(poke['Type 1'].head(0))
print(poke['Type 2'].head(0))
print(poke['HP'].head(0))
print(poke['Attack'].head(0))
print(poke['Defense'].head(0))
print(poke['Sp. Atk'].head(0))
print(poke['Sp. Def'].head(0))
print(poke['Speed'].head(0))
print(poke['Generation'].head(0))
print(poke['Legendary'].head(0))
# Out:
# Series([], Name: #, dtype: int64)
# Series([], Name: Name, dtype: object)
# Series([], Name: Type 1, dtype: object)
# Series([], Name: Type 2, dtype: object)
# Series([], Name: HP, dtype: int64)
# Series([], Name: Attack, dtype: int64)
# Series([], Name: Defense, dtype: int64)
# Series([], Name: Sp. Atk, dtype: int64)
# Series([], Name: Sp. Def, dtype: int64)
# Series([], Name: Speed, dtype: int64)
# Series([], Name: Generation, dtype: int64)
# Series([], Name: Legendary, dtype: bool)

# %% [markdown]
# Punto 3:

# %%
poke.set_index('#', inplace = True)
poke.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Punto 4:

# %%
poke['Attack'].mean()
# Out:
# 79.00125

# %% [markdown]
# Punto 5:

# %%
poke[poke['Generation'] == 1]['Attack'].mean()
# Out:
# 76.63855421686748

# %% [markdown]
# Punto 6:

# %%
poke['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
poke[poke['Legendary'] == True]['Legendary'].value_counts()
# Out:
# True    65
# Name: Legendary, dtype: int64

# %%
poke[poke['Legendary'] == False]['Legendary'].value_counts()
# Out:
# False    735
# Name: Legendary, dtype: int64

# %% [markdown]
# Punto 7:

# %%
poke.sort_values(by = 'HP', ascending = False)
# Out:
#           Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# #
# 242    Blissey   Normal    NaN  255      10       10       75      135     55
# 113    Chansey   Normal    NaN  250       5        5       35      105     50
# 202  Wobbuffet  Psychic    NaN  190      33       58       33       58     33
# 321    Wailord    Water    NaN  170      90       45       90       45     60
# 594  Alomomola    Water    NaN  165      75       80       40       45     65
# ..         ...      ...    ...  ...     ...      ...      ...      ...    ...
# 129   Magikarp    Water    NaN   20      10       55       15       20     80
# 349     Feebas    Water    NaN   20      15       20       10       55     80
# 355    Duskull    Ghost    NaN   20      40       90       30       90     25
# 50     Diglett   Ground    NaN   10      55       25       35       45     95
# 292   Shedinja      Bug  Ghost    1      90       45       30       30     40
#
#      Generation  Legendary
# ...

# %% [markdown]
# ## Ejercicio 2 (5min)
# 1. Utilizando el dataset de los pokemones, calcular para cada pokemon la suma de sus estadísticas (Puntos de salud + Ataque + Defensa + Ataque Especial + Defensa especial + Velocidad)

# %%
import numpy as np

# %%
poke ['suma_estadisticas'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Atk'] + poke['Sp. Def'] + poke['Speed']

# %%
poke.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison  45      49       49       65
# 2                Ivysaur  Grass  Poison  60      62       63       80
# 3               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  suma_estadisticas
# #
# 1       65     45           1      False                318
# 2       80     60           1      False                405
# 3      100     80           1      False                525
# 3      120     80           1      False                625
# 4       50     65           1      False                309
